# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %matplotlib inline

# %%
pd.__version__
# Out:
# '2.0.0'

# %%
url = 'https://raw.githubusercontent.com/Sketchjar/MachineLearningHD/main/bank_marketing_dataset.csv'

# %%
df = pd.read_csv(url)
df.head().T
# Out:
#                           0            1            2            3
# age                      56           57           37           40  \
# job               housemaid     services     services       admin.
# marital             married      married      married      married
# education          basic.4y  high.school  high.school     basic.6y
# default                  no      unknown           no           no
# housing                  no           no          yes           no
# loan                     no           no           no           no
# contact           telephone    telephone    telephone    telephone
# month                   may          may          may          may
# day_of_week             mon          mon          mon          mon
# duration                261          149          226          151
# campaign                  1            1            1            1
# pdays                   999          999          999          999
# previous                  0            0            0            0
# poutcome        nonexistent  nonexistent  nonexistent  nonexistent
# emp.var.rate            1.1          1.1          1.1          1.1
# cons.price.idx       93.994       93.994       93.994       93.994
# cons.conf.idx         -36.4        -36.4        -36.4        -36.4
# euribor3m             4.857        4.857        4.857        4.857
# nr.employed          5191.0       5191.0       5191.0       5191.0
# outcome                  no           no           no           no
#
#                           4
# age                      56
# job                services
# marital             married
# education       high.school
# default                  no
# housing                  no
# loan                    yes
# contact           telephone
# month                   may
# day_of_week             mon
# duration                307
# campaign                  1
# pdays                   999
# previous                  0
# poutcome        nonexistent
# emp.var.rate            1.1
# cons.price.idx       93.994
# cons.conf.idx         -36.4
# euribor3m             4.857
# nr.employed          5191.0
# outcome                  no

# %%
df.sample(10)
# Out:
#        age          job   marital          education  default housing loan
# 24660   35       admin.   married  university.degree       no      no   no  \
# 37810   67      retired  divorced  university.degree       no     yes   no
# 30193   30       admin.    single  university.degree       no      no   no
# 9822    55   unemployed   married           basic.4y  unknown     yes   no
# 34822   35       admin.   married  university.degree       no     yes  yes
# 32014   46       admin.   married        high.school       no     yes   no
# 31764   32       admin.   married        high.school       no      no  yes
# 18592   31   management    single  university.degree       no     yes   no
# 9547    30  blue-collar    single           basic.4y  unknown      no   no
# 37116   54   unemployed   married  university.degree       no     yes  yes
#
#          contact month day_of_week  ...  campaign  pdays  previous
# 24660   cellular   nov         mon  ...         2    999         0  \
# 37810   cellular   aug         wed  ...         5    999         1
# 30193   cellular   apr         thu  ...         1    999         0
# 9822   telephone   jun         wed  ...         4    999         0
# 34822   cellular   may         thu  ...         9    999         0
# 32014  telephone   may         thu  ...         4    999         0
# 31764   cellular   may         thu  ...         1    999         1
# 18592   cellular   jul         thu  ...         3    999         0
# 9547   telephone   jun         mon  ...         1    999         0
# 37116   cellular   jul         thu  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 24660  nonexistent         -0.1          93.200          -42.0      4.191  \
# 37810      failure         -2.9          92.201          -31.4      0.834
# 30193  nonexistent         -1.8          93.075          -47.1      1.365
# 9822   nonexistent          1.4          94.465          -41.8      4.959
# 34822  nonexistent         -1.8          92.893          -46.2      1.266
# 32014  nonexistent         -1.8          92.893          -46.2      1.327
# 31764      failure         -1.8          92.893          -46.2      1.327
# 18592  nonexistent          1.4          93.918          -42.7      4.968
# 9547   nonexistent          1.4          94.465          -41.8      4.961
# 37116  nonexistent         -2.9          92.469          -33.6      0.899
#
#        nr.employed  outcome
# 24660       5195.8       no
# 37810       5076.2       no
# 30193       5099.1       no
# 9822        5228.1       no
# 34822       5099.1       no
# 32014       5099.1       no
# 31764       5099.1       no
# 18592       5228.1       no
# 9547        5228.1      yes
# 37116       5076.2       no
#
# [10 rows x 21 columns]

# %%
df.tail()
# Out:
#        age          job  marital            education default housing loan
# 41183   73      retired  married  professional.course      no     yes   no  \
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous
# 41183  cellular   nov         fri  ...         1    999         0  \
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 41183  nonexistent         -1.1          94.767          -50.8      1.028  \
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed  outcome
# 41183       4963.6      yes
# 41184       4963.6       no
# 41185       4963.6       no
# 41186       4963.6      yes
# 41187       4963.6       no
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'outcome'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=41188, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  outcome         41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
df.describe(include=object)
# Out:
#            job  marital          education default housing   loan   contact
# count    41188    41188              41188   41188   41188  41188     41188  \
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome outcome
# count   41188       41188        41188   41188
# unique     10           5            3       2
# top       may         thu  nonexistent      no
# freq    13769        8623        35563   36548

# %% [markdown]
# Renomear as colunas removendo os pontos

# %%
df.columns = ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx','cons_conf_idx', 'euribor3m', 'nr_employed', 'y']

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact
# 0   56  housemaid  married     basic.4y       no      no   no  telephone  \
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp_var_rate
# 0   may         mon  ...         1    999         0  nonexistent          1.1  \
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.age.hist(bins=50)
# Out:
# <Axes: >

# %%
df.job.isnull().values.sum()
# Out:
# 0

# %%
df.job.value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %% [markdown]
# Trocar os trabalhos desconhecidos por ADMIN

# %%
df.loc[df['job'] == 'unknown', 'job'] = 'admin'

# %%
df.job.value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# admin              330
# Name: count, dtype: int64

# %%
cols = ['job', 'marital', 'education', 'housing', 'loan', 'contact',
       'month', 'day_of_week', 'poutcome']

df_cat = pd.get_dummies(df[cols],drop_first=True)

# %%
df_cat
# Out:
#        job_admin.  job_blue-collar  job_entrepreneur  job_housemaid
# 0           False            False             False           True  \
# 1           False            False             False          False
# 2           False            False             False          False
# 3            True            False             False          False
# 4           False            False             False          False
# ...           ...              ...               ...            ...
# 41183       False            False             False          False
# 41184       False             True             False          False
# 41185       False            False             False          False
# 41186       False            False             False          False
# 41187       False            False             False          False
#
#        job_management  job_retired  job_self-employed  job_services
# 0               False        False              False         False  \
# 1               False        False              False          True
# 2               False        False              False          True
# 3               False        False              False         False
# 4               False        False              False          True
# ...               ...          ...                ...           ...
# 41183           False         True              False         False
# 41184           False        False              False         False
# 41185           False         True              False         False
# 41186           False        False              False         False
# 41187           False         True              False         False
#
#        job_student  job_technician  ...  month_may  month_nov  month_oct
# 0            False           False  ...       True      False      False  \
# 1            False           False  ...       True      False      False
# 2            False           False  ...       True      False      False
# 3            False           False  ...       True      False      False
# 4            False           False  ...       True      False      False
# ...            ...             ...  ...        ...        ...        ...
# 41183        False           False  ...      False       True      False
# 41184        False           False  ...      False       True      False
# 41185        False           False  ...      False       True      False
# 41186        False            True  ...      False       True      False
# 41187        False           False  ...      False       True      False
#
#        month_sep  day_of_week_mon  day_of_week_thu  day_of_week_tue
# 0          False             True            False            False  \
# 1          False             True            False            False
# 2          False             True            False            False
# 3          False             True            False            False
# 4          False             True            False            False
# ...          ...              ...              ...              ...
# 41183      False            False            False            False
# 41184      False            False            False            False
# 41185      False            False            False            False
# 41186      False            False            False            False
# 41187      False            False            False            False
#
#        day_of_week_wed  poutcome_nonexistent  poutcome_success
# 0                False                  True             False
# 1                False                  True             False
# 2                False                  True             False
# 3                False                  True             False
# 4                False                  True             False
# ...                ...                   ...               ...
# 41183            False                  True             False
# 41184            False                  True             False
# 41185            False                  True             False
# 41186            False                  True             False
# 41187            False                 False             False
#
# [41188 rows x 41 columns]

# %%
df_final = pd.concat([df,df_cat],axis=1)

# %%
df.job.unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', 'admin',
#        'entrepreneur', 'student'], dtype=object)

# %%
df.job.nunique()
# Out:
# 12

# %%
df['job'].sort_values().head(5)
# Out:
# 36161    admin
# 1376     admin
# 36323    admin
# 16938    admin
# 16304    admin
# Name: job, dtype: object

# %% [markdown]
# Criar uma tabela dinâmica com índice como coluna de trabalho, colunas como educação e valores como idade

# %%
pd.pivot_table(df, values='age', index=['job'], columns=['education'])
# Out:
# education       basic.4y   basic.6y   basic.9y  high.school  illiterate
# job
# admin          49.538462  42.045455  39.387097    42.162162         NaN  \
# admin.         50.727273  42.980132  41.022044    37.719435   51.000000
# blue-collar    43.494392  38.798036  37.906431    36.227790   49.250000
# entrepreneur   44.496350  38.704225  41.557143    39.636752   51.000000
# housemaid      49.164557  43.766234  42.212766    39.545977   60.000000
# management     49.270000  44.635294  43.120482    41.369128         NaN
# retired        64.445561  59.373333  57.717241    59.351449   54.666667
# self-employed  44.258065  40.960000  41.527273    40.177966   34.000000
# services       46.295455  40.951327  36.737113    37.532438         NaN
# student        22.807692  21.538462  24.171717    24.829132         NaN
# technician     50.620690  41.471264  39.828125    38.431844         NaN
# unemployed     43.785714  42.235294  41.935484    38.355212         NaN
#
# education      professional.course  university.degree    unknown
# job
# admin                    44.500000          37.333333  49.923664
# admin.                   39.336088          37.619677  43.365462
# blue-collar              39.302428          35.904255  42.262115
# entrepreneur             40.940741          41.983607  46.736842
# housemaid                47.745763          41.014388  50.690476
# management               45.112360          41.714493  45.447154
# retired                  60.692946          62.101754  66.530612
# self-employed            40.636905          38.666667  42.827586
# services                 36.724771          35.254335  40.953333
# student                  28.488372          28.600000  26.592814
# technician               38.762952          36.670536  43.575472
# unemployed               40.746479          36.854962  40.736842

# %%
df = pd.get_dummies(df, columns=['job'])

# %%
df.head()
# Out:
#    age  marital    education  default housing loan    contact month
# 0   56  married     basic.4y       no      no   no  telephone   may  \
# 1   57  married  high.school  unknown      no   no  telephone   may
# 2   37  married  high.school       no     yes   no  telephone   may
# 3   40  married     basic.6y       no      no   no  telephone   may
# 4   56  married  high.school       no      no  yes  telephone   may
#
#   day_of_week  duration  ...  job_blue-collar  job_entrepreneur
# 0         mon       261  ...            False             False  \
# 1         mon       149  ...            False             False
# 2         mon       226  ...            False             False
# 3         mon       151  ...            False             False
# 4         mon       307  ...            False             False
#
#    job_housemaid job_management  job_retired  job_self-employed  job_services
# 0           True          False        False              False         False  \
# 1          False          False        False              False          True
# 2          False          False        False              False          True
# 3          False          False        False              False         False
# 4          False          False        False              False          True
#
#    job_student  job_technician job_unemployed
# 0        False           False          False
# 1        False           False          False
# 2        False           False          False
# 3        False           False          False
# 4        False           False          False
#
# [5 rows x 32 columns]

# %%
df = pd.get_dummies(df, columns=['marital'])

# %%
pd.set_option('display.max_row', 1000)

# %%
pd.set_option('display.max_columns', 50)

# %%
df.to_csv('my_data.csv',  sep=';', index=False)
